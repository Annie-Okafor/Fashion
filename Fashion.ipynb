# %%
import pandas as pd # importing pandas library
import numpy as np # importing numpy library

# %%
F_dataset= pd.read_csv('/content/sample_data/fashion dataset.csv')
F_dataset
# Out:
#              p_id                                               name   price  \
# 0       1518329.0   Dupatta Bazaar White Embroidered Chiffon Dupatta   899.0
# 1       5829334.0  Roadster Women Mustard Yellow Solid Hooded Swe...  1199.0
# 2      10340119.0  Inddus Peach-Coloured & Beige Unstitched Dress...  5799.0
# 3      10856380.0            SASSAFRAS Women Black Parallel Trousers  1499.0
# 4      12384822.0  Kotty Women Black Wide Leg High-Rise Clean Loo...  1999.0
# ...           ...                                                ...     ...
# 14324  17029604.0  The Chennai Silks Pink & Silver-Toned Floral Z...  3999.0
# 14325  17600212.0  Kinder Kids Girls Blue & Green Printed Foil Pr...  2050.0
# 14326  18159266.0  KLOTTHE Women Green & Black Floral Printed Pal...  1659.0
# 14327  18921114.0             InWeave Women Red Printed A-Line Skirt  2399.0
# 14328  19361058.0      BoStreet Women Navy Blue Tapered Fit Trousers  2599.0
#
# ...

# %%
F_branddetails= pd.read_csv('/content/sample_data/fashion brand details.csv')
F_branddetails
# Out:
#       brand_id    brand_name
# 0            1           513
# 1            2          109F
# 2            3     20Dresses
# 3            4   250 Designs
# 4            5          3Pin
# ...        ...           ...
# 1015      1016  Ziva Fashion
# 1016      1017        Zivame
# 1017      1018         Ziyaa
# 1018      1019        Zoella
# 1019      1020          Zola
#
# [1020 rows x 2 columns]

# %%
F_dataset.drop(F_dataset.columns[[7,8]], axis=1, inplace=True)
F_dataset
# Out:
#              p_id                                               name   price  \
# 0       1518329.0   Dupatta Bazaar White Embroidered Chiffon Dupatta   899.0
# 1       5829334.0  Roadster Women Mustard Yellow Solid Hooded Swe...  1199.0
# 2      10340119.0  Inddus Peach-Coloured & Beige Unstitched Dress...  5799.0
# 3      10856380.0            SASSAFRAS Women Black Parallel Trousers  1499.0
# 4      12384822.0  Kotty Women Black Wide Leg High-Rise Clean Loo...  1999.0
# ...           ...                                                ...     ...
# 14324  17029604.0  The Chennai Silks Pink & Silver-Toned Floral Z...  3999.0
# 14325  17600212.0  Kinder Kids Girls Blue & Green Printed Foil Pr...  2050.0
# 14326  18159266.0  KLOTTHE Women Green & Black Floral Printed Pal...  1659.0
# 14327  18921114.0             InWeave Women Red Printed A-Line Skirt  2399.0
# 14328  19361058.0      BoStreet Women Navy Blue Tapered Fit Trousers  2599.0
#
# ...

# %%
F_dataset.rename(columns = {'brand':'brand_name'}, inplace = True)
F_dataset
# Out:
#              p_id                                               name   price  \
# 0       1518329.0   Dupatta Bazaar White Embroidered Chiffon Dupatta   899.0
# 1       5829334.0  Roadster Women Mustard Yellow Solid Hooded Swe...  1199.0
# 2      10340119.0  Inddus Peach-Coloured & Beige Unstitched Dress...  5799.0
# 3      10856380.0            SASSAFRAS Women Black Parallel Trousers  1499.0
# 4      12384822.0  Kotty Women Black Wide Leg High-Rise Clean Loo...  1999.0
# ...           ...                                                ...     ...
# 14324  17029604.0  The Chennai Silks Pink & Silver-Toned Floral Z...  3999.0
# 14325  17600212.0  Kinder Kids Girls Blue & Green Printed Foil Pr...  2050.0
# 14326  18159266.0  KLOTTHE Women Green & Black Floral Printed Pal...  1659.0
# 14327  18921114.0             InWeave Women Red Printed A-Line Skirt  2399.0
# 14328  19361058.0      BoStreet Women Navy Blue Tapered Fit Trousers  2599.0
#
# ...

# %%
F_dataset['brand_name'] = F_dataset['brand_name'].str.lower()
F_branddetails['brand_name'] = F_branddetails['brand_name'].str.lower()

# %%
New_Fashion_dataset= pd.merge(F_dataset,F_branddetails, left_on='brand_name', right_on='brand_name')
New_Fashion_dataset
# Out:
#              p_id                                               name   price  \
# 0       1518329.0   Dupatta Bazaar White Embroidered Chiffon Dupatta   899.0
# 1      10711448.0           Dupatta Bazaar Women White Solid Dupatta   599.0
# 2      14964708.0  Dupatta Bazaar Orange & Green Dyed Art Silk Ba...   899.0
# 3      13552234.0                 Dupatta Bazaar Black Solid Dupatta   599.0
# 4      17663032.0        Dupatta Bazaar Women's Solid Orange Dupatta   599.0
# ...           ...                                                ...     ...
# 14300  16630130.0  SHIVANGI clothing Girls Red & White Printed Re...  1595.0
# 14301  18395182.0  ARTICALE Women Off White Solid Slim Fit Cotton...  1699.0
# 14302  18395164.0            ARTICALE Women Lavender Slim Fit Shorts  1699.0
# 14303   2117164.0           Noi Cream-Coloured & Brown Printed Shawl  1999.0
# 14304  18055840.0  tantkatha Black Front Closure Saree Blouse Wit...  1699.0
#
# ...

# %%
New_Fashion_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14305 entries, 0 to 14304
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   p_id         14305 non-null  float64
#  1   name         14305 non-null  object
#  2   price        14305 non-null  float64
#  3   colour       14302 non-null  object
#  4   brand_name   14305 non-null  object
#  5   ratingCount  6578 non-null   float64
#  6   avg_rating   6578 non-null   float64
#  7   brand_id     14305 non-null  int64
# dtypes: float64(4), int64(1), object(3)
# memory usage: 1005.8+ KB

# %%
New_table = New_Fashion_dataset.groupby(New_Fashion_dataset['brand_id'])
New_table.mean()
# Out:
#                   p_id        price  ratingCount  avg_rating
# brand_id
# 1         1.452080e+07  2099.000000    86.500000    4.530008
# 2         1.595497e+07  1832.333333          NaN         NaN
# 3         1.623578e+07  2885.697674    33.625000    4.511200
# 4         1.839546e+07  3499.000000          NaN         NaN
# 5         1.392688e+07  1999.000000          NaN         NaN
# ...                ...          ...          ...         ...
# 1016      1.828963e+07  2999.000000          NaN         NaN
# 1017      1.591479e+07  1046.333333   328.500000    4.398649
# 1018      1.641373e+07  3419.058824   390.142857    3.858065
# 1019      1.463899e+07  3399.000000          NaN         NaN
# 1020      1.573899e+07  3400.590909    24.368421    4.289543
#
# [1020 rows x 4 columns]

# %%
New_table

# %%
New_Fashion_dataset
# Out:
#              p_id                                               name   price  \
# 0       1518329.0   Dupatta Bazaar White Embroidered Chiffon Dupatta   899.0
# 1      10711448.0           Dupatta Bazaar Women White Solid Dupatta   599.0
# 2      14964708.0  Dupatta Bazaar Orange & Green Dyed Art Silk Ba...   899.0
# 3      13552234.0                 Dupatta Bazaar Black Solid Dupatta   599.0
# 4      17663032.0        Dupatta Bazaar Women's Solid Orange Dupatta   599.0
# ...           ...                                                ...     ...
# 14300  16630130.0  SHIVANGI clothing Girls Red & White Printed Re...  1595.0
# 14301  18395182.0  ARTICALE Women Off White Solid Slim Fit Cotton...  1699.0
# 14302  18395164.0            ARTICALE Women Lavender Slim Fit Shorts  1699.0
# 14303   2117164.0           Noi Cream-Coloured & Brown Printed Shawl  1999.0
# 14304  18055840.0  tantkatha Black Front Closure Saree Blouse Wit...  1699.0
#
# ...

# %%
print(New_Fashion_dataset.groupby('brand_id').mean())
# Out:
#                   p_id        price  ratingCount  avg_rating
# brand_id
# 1         1.452080e+07  2099.000000    86.500000    4.530008
# 2         1.595497e+07  1832.333333          NaN         NaN
# 3         1.623578e+07  2885.697674    33.625000    4.511200
# 4         1.839546e+07  3499.000000          NaN         NaN
# 5         1.392688e+07  1999.000000          NaN         NaN
# ...                ...          ...          ...         ...
# 1016      1.828963e+07  2999.000000          NaN         NaN
# 1017      1.591479e+07  1046.333333   328.500000    4.398649
# 1018      1.641373e+07  3419.058824   390.142857    3.858065
# 1019      1.463899e+07  3399.000000          NaN         NaN
# 1020      1.573899e+07  3400.590909    24.368421    4.289543
#
# [1020 rows x 4 columns]

# %%
New_Fashion_dataset.isna()
# Out:
#         p_id   name  price  colour  brand_name  ratingCount  avg_rating  \
# 0      False  False  False   False       False        False       False
# 1      False  False  False   False       False        False       False
# 2      False  False  False   False       False        False       False
# 3      False  False  False   False       False        False       False
# 4      False  False  False   False       False         True        True
# ...      ...    ...    ...     ...         ...          ...         ...
# 14300  False  False  False   False       False         True        True
# 14301  False  False  False   False       False         True        True
# 14302  False  False  False   False       False         True        True
# 14303  False  False  False   False       False        False       False
# 14304  False  False  False   False       False         True        True
#
#        brand_id
# 0         False
# 1         False
# 2         False
# 3         False
# ...

# %%
New_Fashion_dataset.isnull()
# Out:
#         p_id   name  price  colour  brand_name  ratingCount  avg_rating  \
# 0      False  False  False   False       False        False       False
# 1      False  False  False   False       False        False       False
# 2      False  False  False   False       False        False       False
# 3      False  False  False   False       False        False       False
# 4      False  False  False   False       False         True        True
# ...      ...    ...    ...     ...         ...          ...         ...
# 14300  False  False  False   False       False         True        True
# 14301  False  False  False   False       False         True        True
# 14302  False  False  False   False       False         True        True
# 14303  False  False  False   False       False        False       False
# 14304  False  False  False   False       False         True        True
#
#        brand_id
# 0         False
# 1         False
# 2         False
# 3         False
# ...

# %%
newFd=New_Fashion_dataset.copy()
newFd['ratingCount']=newFd['ratingCount'].fillna(newFd.mean())
newFd['avg_rating']=newFd['avg_rating'].fillna(newFd.mean())
newFd.sort_values(by=['brand_id'], inplace=True)
# Out:
# <ipython-input-35-bcbe87887171>:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   newFd['ratingCount']=newFd['ratingCount'].fillna(newFd.mean())
# <ipython-input-35-bcbe87887171>:3: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   newFd['avg_rating']=newFd['avg_rating'].fillna(newFd.mean())

# %%
newFd1=New_Fashion_dataset.copy()
newFd1['ratingCount']=newFd1['ratingCount'].fillna(newFd.mean())
newFd1.sort_values(by=['brand_id'], inplace=True)
# Out:
# <ipython-input-37-e6023b58a2cf>:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   newFd1['ratingCount']=newFd1['ratingCount'].fillna(newFd.mean())

# %%
newFd1
# Out:
#              p_id                                               name   price  \
# 8055   15883214.0      513 Women Black & Grey Checked Poncho Sweater  2499.0
# 8054   13158392.0   513 Women Black & Grey Woven-Design Kimono Shrug  1699.0
# 13838  16920884.0          109F Women Black Striped Relaxed Trousers  1599.0
# 13837  17743260.0                        109F Brown Culotte Jumpsuit  1999.0
# 13839  13200776.0                109F Women Navy Blue Slim Fit Jeans  1899.0
# ...           ...                                                ...     ...
# 9990   14546538.0                     ZOLA Women Blue Slim Fit Jeans  2985.0
# 10019  14541368.0                     ZOLA Women Grey Slim Fit Jeans  2520.0
# 10018  14546496.0  ZOLA Women Blue Mid-Rise Slim Fit Ankle Length...  3525.0
# 10016  14547542.0            ZOLA Killer Women Blue Skinny Fit Jeans  2850.0
# 9997   15853314.0  ZOLA Black Chikankari Embroidered Lucknowi Chi...  3485.0
#
# ...

# %%
newFd2=New_Fashion_dataset.copy()
newFd2['ratingCount'].fillna(newFd2.groupby('brand_id')['ratingCount'].transform('mean'), inplace=True)

# %%
newFd2
# Out:
#              p_id                                               name   price  \
# 0       1518329.0   Dupatta Bazaar White Embroidered Chiffon Dupatta   899.0
# 1      10711448.0           Dupatta Bazaar Women White Solid Dupatta   599.0
# 2      14964708.0  Dupatta Bazaar Orange & Green Dyed Art Silk Ba...   899.0
# 3      13552234.0                 Dupatta Bazaar Black Solid Dupatta   599.0
# 4      17663032.0        Dupatta Bazaar Women's Solid Orange Dupatta   599.0
# ...           ...                                                ...     ...
# 14300  16630130.0  SHIVANGI clothing Girls Red & White Printed Re...  1595.0
# 14301  18395182.0  ARTICALE Women Off White Solid Slim Fit Cotton...  1699.0
# 14302  18395164.0            ARTICALE Women Lavender Slim Fit Shorts  1699.0
# 14303   2117164.0           Noi Cream-Coloured & Brown Printed Shawl  1999.0
# 14304  18055840.0  tantkatha Black Front Closure Saree Blouse Wit...  1699.0
#
# ...

# %%
newFd2['avg_rating'].fillna(newFd2.groupby('brand_id')['avg_rating'].transform('mean'), inplace=True)

# %%
newFd2
# Out:
#              p_id                                               name   price  \
# 0       1518329.0   Dupatta Bazaar White Embroidered Chiffon Dupatta   899.0
# 1      10711448.0           Dupatta Bazaar Women White Solid Dupatta   599.0
# 2      14964708.0  Dupatta Bazaar Orange & Green Dyed Art Silk Ba...   899.0
# 3      13552234.0                 Dupatta Bazaar Black Solid Dupatta   599.0
# 4      17663032.0        Dupatta Bazaar Women's Solid Orange Dupatta   599.0
# ...           ...                                                ...     ...
# 14300  16630130.0  SHIVANGI clothing Girls Red & White Printed Re...  1595.0
# 14301  18395182.0  ARTICALE Women Off White Solid Slim Fit Cotton...  1699.0
# 14302  18395164.0            ARTICALE Women Lavender Slim Fit Shorts  1699.0
# 14303   2117164.0           Noi Cream-Coloured & Brown Printed Shawl  1999.0
# 14304  18055840.0  tantkatha Black Front Closure Saree Blouse Wit...  1699.0
#
# ...

# %%
newFd2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14305 entries, 0 to 14304
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   p_id         14305 non-null  float64
#  1   name         14305 non-null  object
#  2   price        14305 non-null  float64
#  3   colour       14302 non-null  object
#  4   brand_name   14305 non-null  object
#  5   ratingCount  12794 non-null  float64
#  6   avg_rating   12794 non-null  float64
#  7   brand_id     14305 non-null  int64
# dtypes: float64(4), int64(1), object(3)
# memory usage: 1.5+ MB

# %%
newFd2_zero = newFd2.copy()
newFd2_zero['ratingCount']=newFd2_zero['ratingCount'].fillna(0)
newFd2_zero['avg_rating']=newFd2_zero['avg_rating'].fillna(0)
newFd2_zero.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14305 entries, 0 to 14304
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   p_id         14305 non-null  float64
#  1   name         14305 non-null  object
#  2   price        14305 non-null  float64
#  3   colour       14302 non-null  object
#  4   brand_name   14305 non-null  object
#  5   ratingCount  14305 non-null  float64
#  6   avg_rating   14305 non-null  float64
#  7   brand_id     14305 non-null  int64
# dtypes: float64(4), int64(1), object(3)
# memory usage: 1.5+ MB

# %%
newFd2_zero=newFd2_zero.drop_duplicates()
newFd2_zero
# Out:
#              p_id                                               name   price  \
# 0       1518329.0   Dupatta Bazaar White Embroidered Chiffon Dupatta   899.0
# 1      10711448.0           Dupatta Bazaar Women White Solid Dupatta   599.0
# 2      14964708.0  Dupatta Bazaar Orange & Green Dyed Art Silk Ba...   899.0
# 3      13552234.0                 Dupatta Bazaar Black Solid Dupatta   599.0
# 4      17663032.0        Dupatta Bazaar Women's Solid Orange Dupatta   599.0
# ...           ...                                                ...     ...
# 14300  16630130.0  SHIVANGI clothing Girls Red & White Printed Re...  1595.0
# 14301  18395182.0  ARTICALE Women Off White Solid Slim Fit Cotton...  1699.0
# 14302  18395164.0            ARTICALE Women Lavender Slim Fit Shorts  1699.0
# 14303   2117164.0           Noi Cream-Coloured & Brown Printed Shawl  1999.0
# 14304  18055840.0  tantkatha Black Front Closure Saree Blouse Wit...  1699.0
#
# ...

# %%
newFd2_zero.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14221 entries, 0 to 14304
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   p_id         14221 non-null  float64
#  1   name         14221 non-null  object
#  2   price        14221 non-null  float64
#  3   colour       14218 non-null  object
#  4   brand_name   14221 non-null  object
#  5   ratingCount  14221 non-null  float64
#  6   avg_rating   14221 non-null  float64
#  7   brand_id     14221 non-null  int64
# dtypes: float64(4), int64(1), object(3)
# memory usage: 999.9+ KB

# %%
newFd2_zero = newFd2_zero.dropna(axis=0)
newFd2_zero.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14218 entries, 0 to 14304
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   p_id         14218 non-null  float64
#  1   name         14218 non-null  object
#  2   price        14218 non-null  float64
#  3   colour       14218 non-null  object
#  4   brand_name   14218 non-null  object
#  5   ratingCount  14218 non-null  float64
#  6   avg_rating   14218 non-null  float64
#  7   brand_id     14218 non-null  int64
# dtypes: float64(4), int64(1), object(3)
# memory usage: 999.7+ KB

# %%
from google.colab import files

newFd2_zero.to_csv('Fashion.csv')
files.download('Fashion.csv')
